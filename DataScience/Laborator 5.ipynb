# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("Persons.csv") 

ax = plt.gca()

data.plot(kind='line',x='age',y='education-num',ax=ax)
data.plot(kind='line',x='age',y='capital-loss', color='red', ax=ax)
data.plot(kind='line',x='age',y='hours-per-week', color='green', ax=ax)

plt.show()

# %% [markdown]
# ### SOMETHING IS WRONG

# %% [markdown]
# ### I think so...
